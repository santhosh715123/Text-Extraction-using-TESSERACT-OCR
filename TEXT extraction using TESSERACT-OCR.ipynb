# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in /usr/local/lib/python2.7/dist-packages (0.3.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python2.7/dist-packages (from pytesseract) (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python2.7/dist-packages (from Pillow->pytesseract) (0.46)

# %%
import pytesseract
import shutil
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7438a252-a40a-48a9-9e22-1a9ed417bdba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7438a252-a40a-48a9-9e22-1a9ed417bdba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("/content/aadhar-card1.jpg")
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/aadhar-card1.jpg'))

# %%
print(extractedInformation)
# Out:
# Government Of india
#
# Name
# XXX XXXK XXKK
#
# DOB/ xx xx xx
#
# Sex / xxx
#
# YOOX OK KK
#
#
#
# Aadhaar - Aam Aadmi ka Adhikar
# [bankbisranran f
#
#
#
# Address
#
# XXX XXXX XXXX
# XK XKKK XKXK
# XXX XXXX XXXX
# XXX XXXX
#
# fi cation Authority Of
#
# rR. sstctbettstaagatininere.
#
# XXX XXKX XXX
# XXXX XXXX XXX
# XXXX XXXX XXX
# XXX XXXX
#
# XXX XXXX XXX
#
# helpauidal.govin
